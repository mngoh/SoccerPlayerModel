# %% [markdown]
# # Data EDA

# %%
# Load Libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data 
#df  = pd.read_csv('22_eda.csv')
#df = df.drop(['Unnamed: 0'], axis = 1)

# %%
# Load Data 
df = pd.read_excel('data/22_merged_data_final.xlsx')
# Drop Duplicate Players
print('Length Before:' , len(df))
df = df.drop_duplicates(subset=['player'], keep='last')
print('Length After:' , len(df))
# Out:
# Length Before: 21863
# Length After: 2786

# %%
# Remove Object Variables
num = df_22.select_dtypes(exclude=['object']).columns

# %%
# Columns
df.describe()
# Out:
#                age         born          90s          SCA        SCA90  \
# count  2785.000000  2785.000000  2786.000000  2782.000000  2782.000000
# mean     25.232316  1995.420826    13.990883    27.560029     2.122283
# std       4.671950     4.672646    10.934799    31.027493     3.604459
# min      15.000000  1981.000000     0.000000     0.000000     0.000000
# 25%      22.000000  1992.000000     3.500000     3.000000     0.700000
# 50%      25.000000  1996.000000    12.700000    17.000000     1.780000
# 75%      29.000000  1999.000000    22.800000    40.000000     2.800000
# max      40.000000  2006.000000    38.000000   191.000000    90.000000
#
#           PassLive     PassDead         Drib         Sh_x        Fld_x  ...  \
# count  2782.000000  2782.000000  2782.000000  2782.000000  2782.000000  ...
# mean     19.519770     2.497843     1.522646     1.722502     1.443925  ...
# std      21.605385     6.407292     2.864435     2.509942     2.314437  ...
# ...

# %% [markdown]
# # EDA

# %%
# Plt for Goals
x = df['G-PK']
for y in df[num]:
    plt.scatter(x, df[y])
    plt.title(f'Scatter Plot for {y} vs Goals Scored')
    plt.show()

# %%
# Correlation Matrix
corrMatrix = df.corr().abs()
upper = corrMatrix.where(np.triu(np.ones(corrMatrix.shape), k=1).astype(bool))
plt.rcParams["figure.figsize"]=10,10
sns.heatmap(upper, annot=True)
plt.show()
